# %%
import math
import random

# %%
import random

def play():
    user = input(" ¿Qué vas a usar? 'piedra','papel','tijeras' ")
    computer = random.choice (['piedra', 'papel', 'tijeras'])
     
    if user == computer:
        return 'Es un Empate'
    
    if is_win(user, computer):
        return '¡Ganaste!'
    return '¡Perdiste!'

def is_win(player, opponent):
    if (player == 'piedra' and opponent == 'tijeras') or (player == 'tijeras' and opponent == 'papel') \
        or (player == 'papel' and opponent == 'tijera'):
        return True
    
print(play())
# Out:
# ¡Perdiste!

# %%
for i in range(5):
    print(f"ronda{i + 1}:")  
    resultado= play()
    print(resultado)
    print()
# Out:
# ronda1:
# ¡Perdiste!
#
# ronda2:
# ¡Ganaste!
#
# ronda3:
# Es un Empate
#
# ronda4:
# ¡Ganaste!
#
# ronda5:
# Es un Empate

# %%
#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
import random

chars='!"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
password= ""
lengthpw=int(input("que longitud para la contraseña"))

for _ in range (lengthpw):
    password+= random.choice(chars)
print(password)
# Out:
# IqW)qX4,
